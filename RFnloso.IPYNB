# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    precision_recall_fscore_support,
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    confusion_matrix,
    roc_auc_score
)
from sklearn.utils import shuffle
import joblib


# ============================================================
# 0) CPU Random Forest
# ============================================================

print("Using scikit-learn RandomForest on CPU.")


# ============================================================
# 1) Paths and basic settings  (WINDOWS PATHS USED)
# ============================================================

DATA_PATH = Path(r"C:\Users\LENOVO\Desktop\sen\sen\DATA_MARGED\FUSED_ALL_FINAL_FROM_DATA_ALL.csv")
MODELS_DIR = Path(r"C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu")

SUBJECT_COL = "subject"
LABEL_COL   = "label"

RANDOM_STATE = 42
N_OUTER_FOLDS = 10
N_INNER_FOLDS = 10

os.makedirs(MODELS_DIR, exist_ok=True)
np.random.seed(RANDOM_STATE)


# ============================================================
# 2) Helper functions
# ============================================================

def make_subject_folds(subject_ids, n_folds=10, random_state=42):
    """Split subjects into n folds (subject-wise)."""
    unique_subjects = np.array(sorted(np.unique(subject_ids)))
    rng = np.random.RandomState(random_state)
    rng.shuffle(unique_subjects)
    folds = np.array_split(unique_subjects, n_folds)
    return folds


def undersample_multiclass(X, y, max_ratio=3.0, random_state=42):
    """Random undersampling for multi-class imbalance."""
    rng = np.random.RandomState(random_state)
    X = np.asarray(X)
    y = np.asarray(y)

    classes, counts = np.unique(y, return_counts=True)
    min_count = counts.min()
    max_per_class = {c: int(min_count * max_ratio) for c in classes}

    keep_idx = []

    for c in classes:
        idx = np.where(y == c)[0]
        n_keep = min(len(idx), max_per_class[c])
        chosen = rng.choice(idx, size=n_keep, replace=False)
        keep_idx.append(chosen)

    keep_idx = np.concatenate(keep_idx)
    keep_idx = shuffle(keep_idx, random_state=random_state)

    return X[keep_idx], y[keep_idx]


def get_cpu_rf(params):
    """Return sklearn RF model with given hyperparameters."""
    return RandomForestClassifier(
        n_estimators=params["n_estimators"],
        max_depth=params["max_depth"],
        max_features=params["max_features"],
        bootstrap=params["bootstrap"],
        random_state=RANDOM_STATE,
        n_jobs=-1,
        criterion="gini",
    )


def rf_fit_predict_proba_cpu(X_train, y_train, X_val, params):
    """Train RF and predict probabilities."""
    rf = get_cpu_rf(params)
    rf.fit(X_train, y_train)
    return rf, rf.predict_proba(X_val)


def rf_fit_predict_cpu(X_train, y_train, X_test, params):
    """Train RF and predict labels."""
    rf = get_cpu_rf(params)
    rf.fit(X_train, y_train)
    return rf, rf.predict(X_test)


def evaluate_metrics(y_true, y_pred, label_set=None):
    """Compute all metrics including confusion components."""
    if label_set is None:
        label_set = np.unique(y_true)

    prec, rec, f1, support = precision_recall_fscore_support(
        y_true, y_pred, labels=label_set, zero_division=0
    )

    acc = accuracy_score(y_true, y_pred)
    bal_acc = balanced_accuracy_score(y_true, y_pred)
    micro_f1 = f1_score(y_true, y_pred, average="micro")
    macro_f1 = f1_score(y_true, y_pred, average="macro")
    weighted_f1 = f1_score(y_true, y_pred, average="weighted")
    cm = confusion_matrix(y_true, y_pred, labels=label_set)

    return {
        "labels": label_set,
        "precision": prec,
        "recall": rec,
        "f1": f1,
        "support": support,
        "accuracy": acc,
        "balanced_accuracy": bal_acc,
        "micro_f1": micro_f1,
        "macro_f1": macro_f1,
        "weighted_f1": weighted_f1,
        "cm": cm,
    }


def print_metrics(m, header=""):
    """Pretty-print metrics."""
    print("\n" + "=" * 70)
    print(header)
    print("=" * 70)

    labels = m["labels"]
    cm = m["cm"]

    print("\nPer-class metrics:")
    print("Label | Precision | Recall | F1 | Support")
    for i, c in enumerate(labels):
        print(f"{c:5d} | {m['precision'][i]:.4f} | {m['recall'][i]:.4f} | {m['f1'][i]:.4f} | {m['support'][i]}")

    print("\nGlobal metrics:")
    print(f"Accuracy          : {m['accuracy']:.4f}")
    print(f"Balanced Accuracy : {m['balanced_accuracy']:.4f}")
    print(f"Micro-F1          : {m['micro_f1']:.4f}")
    print(f"Macro-F1          : {m['macro_f1']:.4f}")
    print(f"Weighted-F1       : {m['weighted_f1']:.4f}")

    print("\nConfusion Matrix:")
    print(cm)

    total = cm.sum()
    print("\nTP / FP / FN / TN per class:")
    for idx, c in enumerate(labels):
        TP = cm[idx, idx]
        FP = cm[:, idx].sum() - TP
        FN = cm[idx, :].sum() - TP
        TN = total - (TP + FP + FN)
        print(f"Class {c}: TP={TP}, FP={FP}, FN={FN}, TN={TN}")


def compute_inner_auc(
    X, y, subjects, label_set, param_grid, n_inner_folds=10, max_ratio=3.0
):
    """Inner-loop ROC AUC tuning."""
    inner_folds = make_subject_folds(subjects, n_folds=n_inner_folds, random_state=RANDOM_STATE)
    combo_scores = []

    print("\n------------------------------------------------------")
    print("Inner loop ROC AUC hyperparameter tuning")
    print("------------------------------------------------------")

    for idx, params in enumerate(param_grid):
        fold_aucs = []

        for inner_idx, val_subj in enumerate(inner_folds):
            is_val = np.isin(subjects, val_subj)
            is_train = ~is_val

            X_tr = X[is_train]
            y_tr = y[is_train]
            X_val = X[is_val]
            y_val = y[is_val]

            # undersample
            X_tr_bal, y_tr_bal = undersample_multiclass(
                X_tr, y_tr, max_ratio=max_ratio, random_state=RANDOM_STATE + inner_idx
            )

            _, y_proba = rf_fit_predict_proba_cpu(X_tr_bal, y_tr_bal, X_val, params)

            try:
                auc = roc_auc_score(
                    y_val, y_proba, labels=label_set,
                    multi_class="ovr", average="macro"
                )
                fold_aucs.append(auc)
            except:
                continue

        mean_auc = np.mean(fold_aucs) if len(fold_aucs) > 0 else np.nan
        combo_scores.append((params, mean_auc))
        print(f"Combo {idx+1}/{len(param_grid)} {params} → mean ROC AUC = {mean_auc:.4f}")

    # choose best
    valid = [c for c in combo_scores if not np.isnan(c[1])]
    best_params, best_auc = max(valid, key=lambda x: x[1])

    print("\nBest inner params:", best_params)
    print("Best inner ROC AUC:", best_auc)

    return best_params, best_auc


# ============================================================
# 3) Load dataset
# ============================================================

print("\nLoading dataset...")
df = pd.read_csv(DATA_PATH)
print("Data shape:", df.shape)


# ============================================================
# 4) Ensure only NUMERIC features (prevents all crashes)
# ============================================================

print("\nFiltering numeric columns only...")

df_numeric = df.select_dtypes(include=[np.number]).copy()

meta_cols = [SUBJECT_COL, LABEL_COL]
meta_cols = [c for c in meta_cols if c in df_numeric.columns]

feature_cols = [c for c in df_numeric.columns if c not in meta_cols]

print(f"Numeric feature columns: {len(feature_cols)}")

X_all = df_numeric[feature_cols].values
y_all = df[LABEL_COL].values
subjects_all = df[SUBJECT_COL].values
label_set = np.unique(y_all)




param_grid = []
for ne in [300, 400, 500]:      
    for md in [16, 24, 32]:      
        for mf in ["sqrt"]:      
            param_grid.append({
                "n_estimators": ne,
                "max_depth": md,
                "max_features": mf,
                "bootstrap": True,
            })

print("\nTotal hyperparameter combinations:", len(param_grid))


# ============================================================
# 6) Outer Loop (10 folds)
# ============================================================

outer_folds = make_subject_folds(subjects_all, n_folds=N_OUTER_FOLDS, random_state=RANDOM_STATE)

all_true = []
all_pred = []

outer_best_params = []
outer_best_auc = []
outer_f1 = []

for outer_idx, test_subj in enumerate(outer_folds, start=1):

    print("\n" + "#"*80)
    print(f"OUTER Fold {outer_idx}/10")
    print("#"*80)

    is_test = np.isin(subjects_all, test_subj)
    is_trainval = ~is_test

    X_trval = X_all[is_trainval]
    y_trval = y_all[is_trainval]
    subj_trval = subjects_all[is_trainval]

    X_test = X_all[is_test]
    y_test = y_all[is_test]

    print("Train+Val subjects:", len(np.unique(subj_trval)))
    print("Test subjects:", len(np.unique(test_subj)))

    # -------------------------
    # INNER LOOP (AUC tuning)
    # -------------------------
    best_params, best_auc = compute_inner_auc(
        X_trval, y_trval, subj_trval,
        label_set, param_grid,
        n_inner_folds=N_INNER_FOLDS
    )

    outer_best_params.append(best_params)
    outer_best_auc.append(best_auc)

    # -------------------------
    # Train FINAL model for this outer fold
    # -------------------------
    X_trval_bal, y_trval_bal = undersample_multiclass(
        X_trval, y_trval, max_ratio=3.0, random_state=RANDOM_STATE + outer_idx
    )

    model, y_pred = rf_fit_predict_cpu(X_trval_bal, y_trval_bal, X_test, best_params)

    # save model
    model_path = MODELS_DIR / f"rf_outer_{outer_idx:02d}.pkl"
    joblib.dump(model, model_path)
    print("Saved model:", model_path)

    # evaluation
    m = evaluate_metrics(y_test, y_pred, label_set)
    print_metrics(m, header=f"OUTER Fold {outer_idx} Test Metrics")

    all_true.append(y_test)
    all_pred.append(y_pred)
    outer_f1.append(m["macro_f1"])


# ============================================================
# 7) GLOBAL METRICS
# ============================================================

all_true = np.concatenate(all_true)
all_pred = np.concatenate(all_pred)

global_m = evaluate_metrics(all_true, all_pred, label_set)
print_metrics(global_m, header="GLOBAL Metrics Across All 10 OUTER Folds")


# ============================================================
# 8) Save AUC summary
# ============================================================

rows = []
for i, (p, auc_val) in enumerate(zip(outer_best_params, outer_best_auc), start=1):
    rows.append({
        "outer_fold": i,
        "best_inner_mean_roc_auc": auc_val,
        "n_estimators": p["n_estimators"],
        "max_depth": p["max_depth"],
        "max_features": p["max_features"],
        "bootstrap": p["bootstrap"],
    })

auc_df = pd.DataFrame(rows)
auc_path = MODELS_DIR / "inner_auc_summary.csv"
auc_df.to_csv(auc_path, index=False)

print("\nSaved inner AUC summary to:", auc_path)


# ============================================================
# 9) FINAL DEPLOYMENT MODEL
# ============================================================

from collections import defaultdict

count = defaultdict(int)
sum_f1 = defaultdict(float)

for params, f1_val in zip(outer_best_params, outer_f1):
    key = tuple(sorted(params.items()))
    count[key] += 1
    sum_f1[key] += float(f1_val)

best_key = None
best_count = -1
best_f1sum = -np.inf

for k in count:
    if count[k] > best_count or (count[k] == best_count and sum_f1[k] > best_f1sum):
        best_key = k
        best_count = count[k]
        best_f1sum = sum_f1[k]

final_params = dict(best_key)

print("\nSelected FINAL deployment hyperparameters:", final_params)

# undersample full data
X_full_bal, y_full_bal = undersample_multiclass(
    X_all, y_all, max_ratio=3.0, random_state=999
)

final_model, _ = rf_fit_predict_cpu(
    X_full_bal, y_full_bal, X_full_bal, final_params
)

final_path = MODELS_DIR / "rf_final_deployment.pkl"
joblib.dump(final_model, final_path)

print("\nFinal deployment model saved to:", final_path)
print("Use this model for real-time predictions.")
# Out:
# Using scikit-learn RandomForest on CPU.
#
# Loading dataset...
# Data shape: (1622677, 86)
#
# Filtering numeric columns only...
# Numeric feature columns: 83
#
# Total hyperparameter combinations: 9
#
# ################################################################################
# OUTER Fold 1/10
# ################################################################################
# Train+Val subjects: 101
# Test subjects: 12
#
# ------------------------------------------------------
# Inner loop ROC AUC hyperparameter tuning
# ------------------------------------------------------
# Combo 1/9 {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6245
# Combo 2/9 {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6225
# Combo 3/9 {'n_estimators': 300, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6196
# Combo 4/9 {'n_estimators': 400, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6250
# Combo 5/9 {'n_estimators': 400, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6226
# Combo 6/9 {'n_estimators': 400, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6202
# Combo 7/9 {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6251
# Combo 8/9 {'n_estimators': 500, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6227
# Combo 9/9 {'n_estimators': 500, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6206
#
# Best inner params: {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True}
# Best inner ROC AUC: 0.6251265140314753
# Saved model: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_outer_01.pkl
#
# ======================================================================
# OUTER Fold 1 Test Metrics
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.7951 | 0.9145 | 0.8506 | 118025
#     1 | 0.2324 | 0.0681 | 0.1054 | 29174
#     2 | 0.0975 | 0.2795 | 0.1446 | 1553
#
# Global metrics:
# Accuracy          : 0.7419
# Balanced Accuracy : 0.4207
# Micro-F1          : 0.7419
# Macro-F1          : 0.3669
# Weighted-F1       : 0.6971
#
# Confusion Matrix:
# [[107933   6518   3574]
#  [ 26743   1988    443]
#  [  1071     48    434]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=107933, FP=27814, FN=10092, TN=2913
# Class 1: TP=1988, FP=6566, FN=27186, TN=113012
# Class 2: TP=434, FP=4017, FN=1119, TN=143182
#
# ################################################################################
# OUTER Fold 2/10
# ################################################################################
# Train+Val subjects: 101
# Test subjects: 12
#
# ------------------------------------------------------
# Inner loop ROC AUC hyperparameter tuning
# ------------------------------------------------------
# Combo 1/9 {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6333
# Combo 2/9 {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6301
# Combo 3/9 {'n_estimators': 300, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6301
# Combo 4/9 {'n_estimators': 400, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6335
# Combo 5/9 {'n_estimators': 400, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6310
# Combo 6/9 {'n_estimators': 400, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6306
# Combo 7/9 {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6341
# Combo 8/9 {'n_estimators': 500, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6318
# Combo 9/9 {'n_estimators': 500, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6308
#
# Best inner params: {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True}
# Best inner ROC AUC: 0.6340599196047905
# Saved model: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_outer_02.pkl
#
# ======================================================================
# OUTER Fold 2 Test Metrics
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.8213 | 0.8848 | 0.8519 | 71955
#     1 | 0.2306 | 0.1349 | 0.1702 | 15414
#     2 | 0.2595 | 0.4198 | 0.3207 | 1353
#
# Global metrics:
# Accuracy          : 0.7474
# Balanced Accuracy : 0.4798
# Micro-F1          : 0.7474
# Macro-F1          : 0.4476
# Weighted-F1       : 0.7253
#
# Confusion Matrix:
# [[63665  6868  1422]
#  [13136  2079   199]
#  [  717    68   568]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=63665, FP=13853, FN=8290, TN=2914
# Class 1: TP=2079, FP=6936, FN=13335, TN=66372
# Class 2: TP=568, FP=1621, FN=785, TN=85748
#
# ################################################################################
# OUTER Fold 3/10
# ################################################################################
# Train+Val subjects: 101
# Test subjects: 12
#
# ------------------------------------------------------
# Inner loop ROC AUC hyperparameter tuning
# ------------------------------------------------------
# Combo 1/9 {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6270
# Combo 2/9 {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6240
# Combo 3/9 {'n_estimators': 300, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6220
# Combo 4/9 {'n_estimators': 400, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6273
# Combo 5/9 {'n_estimators': 400, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6250
# Combo 6/9 {'n_estimators': 400, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6235
# Combo 7/9 {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6276
# Combo 8/9 {'n_estimators': 500, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6252
# Combo 9/9 {'n_estimators': 500, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6244
#
# Best inner params: {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True}
# Best inner ROC AUC: 0.6275675224841297
# Saved model: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_outer_03.pkl
#
# ======================================================================
# OUTER Fold 3 Test Metrics
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.7963 | 0.8670 | 0.8302 | 134322
#     1 | 0.2657 | 0.1673 | 0.2053 | 34765
#     2 | 0.1197 | 0.1697 | 0.1404 | 2286
#
# Global metrics:
# Accuracy          : 0.7158
# Balanced Accuracy : 0.4013
# Micro-F1          : 0.7158
# Macro-F1          : 0.3920
# Weighted-F1       : 0.6942
#
# Confusion Matrix:
# [[116457  15761   2104]
#  [ 28199   5816    750]
#  [  1586    312    388]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=116457, FP=29785, FN=17865, TN=7266
# Class 1: TP=5816, FP=16073, FN=28949, TN=120535
# Class 2: TP=388, FP=2854, FN=1898, TN=166233
#
# ################################################################################
# OUTER Fold 4/10
# ################################################################################
# Train+Val subjects: 102
# Test subjects: 11
#
# ------------------------------------------------------
# Inner loop ROC AUC hyperparameter tuning
# ------------------------------------------------------
# Combo 1/9 {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6405
# Combo 2/9 {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6364
# Combo 3/9 {'n_estimators': 300, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6358
# Combo 4/9 {'n_estimators': 400, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6405
# Combo 5/9 {'n_estimators': 400, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6368
# Combo 6/9 {'n_estimators': 400, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6366
# Combo 7/9 {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6405
# Combo 8/9 {'n_estimators': 500, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6371
# Combo 9/9 {'n_estimators': 500, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6369
#
# Best inner params: {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True}
# Best inner ROC AUC: 0.6404940550814792
# Saved model: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_outer_04.pkl
#
# ======================================================================
# OUTER Fold 4 Test Metrics
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.8227 | 0.8704 | 0.8459 | 104119
#     1 | 0.1560 | 0.0866 | 0.1114 | 21317
#     2 | 0.0795 | 0.3051 | 0.1262 | 1216
#
# Global metrics:
# Accuracy          : 0.7330
# Balanced Accuracy : 0.4207
# Micro-F1          : 0.7330
# Macro-F1          : 0.3612
# Weighted-F1       : 0.7154
#
# Confusion Matrix:
# [[90623  9922  3574]
#  [18751  1847   719]
#  [  776    69   371]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=90623, FP=19527, FN=13496, TN=3006
# Class 1: TP=1847, FP=9991, FN=19470, TN=95344
# Class 2: TP=371, FP=4293, FN=845, TN=121143
#
# ################################################################################
# OUTER Fold 5/10
# ################################################################################
# Train+Val subjects: 102
# Test subjects: 11
#
# ------------------------------------------------------
# Inner loop ROC AUC hyperparameter tuning
# ------------------------------------------------------
# Combo 1/9 {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6310
# Combo 2/9 {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6250
# Combo 3/9 {'n_estimators': 300, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6260
# Combo 4/9 {'n_estimators': 400, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6308
# Combo 5/9 {'n_estimators': 400, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6253
# Combo 6/9 {'n_estimators': 400, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6262
# Combo 7/9 {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6309
# Combo 8/9 {'n_estimators': 500, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6255
# Combo 9/9 {'n_estimators': 500, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6262
#
# Best inner params: {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True}
# Best inner ROC AUC: 0.631023737945034
# Saved model: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_outer_05.pkl
#
# ======================================================================
# OUTER Fold 5 Test Metrics
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.7898 | 0.8028 | 0.7963 | 210343
#     1 | 0.2814 | 0.2278 | 0.2518 | 58623
#     2 | 0.1392 | 0.4164 | 0.2086 | 3874
#
# Global metrics:
# Accuracy          : 0.6738
# Balanced Accuracy : 0.4823
# Micro-F1          : 0.6738
# Macro-F1          : 0.4189
# Weighted-F1       : 0.6709
#
# Confusion Matrix:
# [[168867  33651   7825]
#  [ 43119  13354   2150]
#  [  1812    449   1613]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=168867, FP=44931, FN=41476, TN=17566
# Class 1: TP=13354, FP=34100, FN=45269, TN=180117
# Class 2: TP=1613, FP=9975, FN=2261, TN=258991
#
# ################################################################################
# OUTER Fold 6/10
# ################################################################################
# Train+Val subjects: 102
# Test subjects: 11
#
# ------------------------------------------------------
# Inner loop ROC AUC hyperparameter tuning
# ------------------------------------------------------
# Combo 1/9 {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6287
# Combo 2/9 {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6277
# Combo 3/9 {'n_estimators': 300, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6255
# Combo 4/9 {'n_estimators': 400, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6283
# Combo 5/9 {'n_estimators': 400, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6282
# Combo 6/9 {'n_estimators': 400, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6264
# Combo 7/9 {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6279
# Combo 8/9 {'n_estimators': 500, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6284
# Combo 9/9 {'n_estimators': 500, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6269
#
# Best inner params: {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True}
# Best inner ROC AUC: 0.6286671002483482
# Saved model: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_outer_06.pkl
#
# ======================================================================
# OUTER Fold 6 Test Metrics
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.8059 | 0.9396 | 0.8677 | 124554
#     1 | 0.2437 | 0.0381 | 0.0659 | 28842
#     2 | 0.1016 | 0.2955 | 0.1512 | 1929
#
# Global metrics:
# Accuracy          : 0.7642
# Balanced Accuracy : 0.4244
# Micro-F1          : 0.7642
# Macro-F1          : 0.3616
# Weighted-F1       : 0.7099
#
# Confusion Matrix:
# [[117031   3353   4170]
#  [ 26875   1098    869]
#  [  1305     54    570]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=117031, FP=28180, FN=7523, TN=2591
# Class 1: TP=1098, FP=3407, FN=27744, TN=123076
# Class 2: TP=570, FP=5039, FN=1359, TN=148357
#
# ################################################################################
# OUTER Fold 7/10
# ################################################################################
# Train+Val subjects: 102
# Test subjects: 11
#
# ------------------------------------------------------
# Inner loop ROC AUC hyperparameter tuning
# ------------------------------------------------------
# Combo 1/9 {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6380
# Combo 2/9 {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6346
# Combo 3/9 {'n_estimators': 300, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6341
# Combo 4/9 {'n_estimators': 400, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6385
# Combo 5/9 {'n_estimators': 400, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6352
# Combo 6/9 {'n_estimators': 400, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6341
# Combo 7/9 {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6387
# Combo 8/9 {'n_estimators': 500, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6355
# Combo 9/9 {'n_estimators': 500, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6346
#
# Best inner params: {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True}
# Best inner ROC AUC: 0.6387396686095664
# Saved model: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_outer_07.pkl
#
# ======================================================================
# OUTER Fold 7 Test Metrics
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.8080 | 0.8375 | 0.8225 | 84867
#     1 | 0.2692 | 0.1929 | 0.2248 | 20684
#     2 | 0.0714 | 0.1859 | 0.1032 | 1727
#
# Global metrics:
# Accuracy          : 0.7027
# Balanced Accuracy : 0.4054
# Micro-F1          : 0.7027
# Macro-F1          : 0.3835
# Weighted-F1       : 0.6956
#
# Confusion Matrix:
# [[71073 10469  3325]
#  [15846  3990   848]
#  [ 1045   361   321]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=71073, FP=16891, FN=13794, TN=5520
# Class 1: TP=3990, FP=10830, FN=16694, TN=75764
# Class 2: TP=321, FP=4173, FN=1406, TN=101378
#
# ################################################################################
# OUTER Fold 8/10
# ################################################################################
# Train+Val subjects: 102
# Test subjects: 11
#
# ------------------------------------------------------
# Inner loop ROC AUC hyperparameter tuning
# ------------------------------------------------------
# Combo 1/9 {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6227
# Combo 2/9 {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6234
# Combo 3/9 {'n_estimators': 300, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6204
# Combo 4/9 {'n_estimators': 400, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6232
# Combo 5/9 {'n_estimators': 400, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6227
# Combo 6/9 {'n_estimators': 400, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6213
# Combo 7/9 {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6234
# Combo 8/9 {'n_estimators': 500, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6228
# Combo 9/9 {'n_estimators': 500, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6225
#
# Best inner params: {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True}
# Best inner ROC AUC: 0.6234493553478231
# Saved model: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_outer_08.pkl
#
# ======================================================================
# OUTER Fold 8 Test Metrics
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.8774 | 0.7947 | 0.8340 | 124514
#     1 | 0.2091 | 0.2729 | 0.2368 | 20462
#     2 | 0.0836 | 0.4647 | 0.1417 | 1205
#
# Global metrics:
# Accuracy          : 0.7189
# Balanced Accuracy : 0.5108
# Micro-F1          : 0.7189
# Macro-F1          : 0.4041
# Weighted-F1       : 0.7447
#
# Confusion Matrix:
# [[98949 21028  4537]
#  [13274  5584  1604]
#  [  553    92   560]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=98949, FP=13827, FN=25565, TN=7840
# Class 1: TP=5584, FP=21120, FN=14878, TN=104599
# Class 2: TP=560, FP=6141, FN=645, TN=138835
#
# ################################################################################
# OUTER Fold 9/10
# ################################################################################
# Train+Val subjects: 102
# Test subjects: 11
#
# ------------------------------------------------------
# Inner loop ROC AUC hyperparameter tuning
# ------------------------------------------------------
# Combo 1/9 {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6309
# Combo 2/9 {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6316
# Combo 3/9 {'n_estimators': 300, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6312
# Combo 4/9 {'n_estimators': 400, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6315
# Combo 5/9 {'n_estimators': 400, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6315
# Combo 6/9 {'n_estimators': 400, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6312
# Combo 7/9 {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6321
# Combo 8/9 {'n_estimators': 500, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6314
# Combo 9/9 {'n_estimators': 500, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6307
#
# Best inner params: {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True}
# Best inner ROC AUC: 0.6320646375113351
# Saved model: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_outer_09.pkl
#
# ======================================================================
# OUTER Fold 9 Test Metrics
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.8536 | 0.9299 | 0.8901 | 193928
#     1 | 0.1852 | 0.0723 | 0.1041 | 31032
#     2 | 0.1111 | 0.1673 | 0.1335 | 3138
#
# Global metrics:
# Accuracy          : 0.8027
# Balanced Accuracy : 0.3898
# Micro-F1          : 0.8027
# Macro-F1          : 0.3759
# Weighted-F1       : 0.7728
#
# Confusion Matrix:
# [[180330   9812   3786]
#  [ 28371   2245    416]
#  [  2551     62    525]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=180330, FP=30922, FN=13598, TN=3248
# Class 1: TP=2245, FP=9874, FN=28787, TN=187192
# Class 2: TP=525, FP=4202, FN=2613, TN=220758
#
# ################################################################################
# OUTER Fold 10/10
# ################################################################################
# Train+Val subjects: 102
# Test subjects: 11
#
# ------------------------------------------------------
# Inner loop ROC AUC hyperparameter tuning
# ------------------------------------------------------
# Combo 1/9 {'n_estimators': 300, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6210
# Combo 2/9 {'n_estimators': 300, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6163
# Combo 3/9 {'n_estimators': 300, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6167
# Combo 4/9 {'n_estimators': 400, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6213
# Combo 5/9 {'n_estimators': 400, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6161
# Combo 6/9 {'n_estimators': 400, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6172
# Combo 7/9 {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6215
# Combo 8/9 {'n_estimators': 500, 'max_depth': 24, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6169
# Combo 9/9 {'n_estimators': 500, 'max_depth': 32, 'max_features': 'sqrt', 'bootstrap': True} → mean ROC AUC = 0.6171
#
# Best inner params: {'n_estimators': 500, 'max_depth': 16, 'max_features': 'sqrt', 'bootstrap': True}
# Best inner ROC AUC: 0.6214763984136894
# Saved model: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_outer_10.pkl
#
# ======================================================================
# OUTER Fold 10 Test Metrics
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.8441 | 0.8973 | 0.8699 | 146289
#     1 | 0.3351 | 0.1959 | 0.2473 | 29531
#     2 | 0.1341 | 0.3833 | 0.1987 | 1636
#
# Global metrics:
# Accuracy          : 0.7759
# Balanced Accuracy : 0.4922
# Micro-F1          : 0.7759
# Macro-F1          : 0.4386
# Weighted-F1       : 0.7601
#
# Confusion Matrix:
# [[131272  11363   3654]
#  [ 23350   5786    395]
#  [   893    116    627]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=131272, FP=24243, FN=15017, TN=6924
# Class 1: TP=5786, FP=11479, FN=23745, TN=136446
# Class 2: TP=627, FP=4049, FN=1009, TN=171771
#
# ======================================================================
# GLOBAL Metrics Across All 10 OUTER Folds
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.8210 | 0.8730 | 0.8462 | 1312916
#     1 | 0.2514 | 0.1511 | 0.1887 | 289844
#     2 | 0.1142 | 0.3001 | 0.1654 | 19917
#
# Global metrics:
# Accuracy          : 0.7370
# Balanced Accuracy : 0.4414
# Micro-F1          : 0.7370
# Macro-F1          : 0.4001
# Weighted-F1       : 0.7204
#
# Confusion Matrix:
# [[1146200  128745   37971]
#  [ 237664   43787    8393]
#  [  12309    1631    5977]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=1146200, FP=249973, FN=166716, TN=59788
# Class 1: TP=43787, FP=130376, FN=246057, TN=1202457
# Class 2: TP=5977, FP=46364, FN=13940, TN=1556396
#
# Saved inner AUC summary to: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\inner_auc_summary.csv
#
# Selected FINAL deployment hyperparameters: {'bootstrap': True, 'max_depth': 16, 'max_features': 'sqrt', 'n_estimators': 500}
#
# Final deployment model saved to: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\rf_final_deployment.pkl
# Use this model for real-time predictions.

# %%
print_metrics(global_m, header="GLOBAL Metrics Across All 10 OUTER Folds")
# Out:
# ======================================================================
# GLOBAL Metrics Across All 10 OUTER Folds
# ======================================================================
#
# Per-class metrics:
# Label | Precision | Recall | F1 | Support
#     0 | 0.8210 | 0.8730 | 0.8462 | 1312916
#     1 | 0.2514 | 0.1511 | 0.1887 | 289844
#     2 | 0.1142 | 0.3001 | 0.1654 | 19917
#
# Global metrics:
# Accuracy          : 0.7370
# Balanced Accuracy : 0.4414
# Micro-F1          : 0.7370
# Macro-F1          : 0.4001
# Weighted-F1       : 0.7204
#
# Confusion Matrix:
# [[1146200  128745   37971]
#  [ 237664   43787    8393]
#  [  12309    1631    5977]]
#
# TP / FP / FN / TN per class:
# Class 0: TP=1146200, FP=249973, FN=166716, TN=59788
# Class 1: TP=43787, FP=130376, FN=246057, TN=1202457
# Class 2: TP=5977, FP=46364, FN=13940, TN=1556396

# %%
global_metrics_path = MODELS_DIR / "global_metrics_summary.txt"
with open(global_metrics_path, "w", encoding="utf-8") as f:
    from pprint import pprint
    pprint(global_m, stream=f)

print("\nSaved GLOBAL metrics to:", global_metrics_path)
# Out:
# Saved GLOBAL metrics to: C:\Users\LENOVO\Desktop\sen\sen\models_nested_rf_nlnso_cpu\global_metrics_summary.txt
